# %%
from pathlib import Path

from siteparser import conf
from siteparser import SiteParser

# %%
fpath = conf.LOCAL_DIR / "locations.json"
parser = SiteParser(fpath)

# %%
shaker1 = parser.devices['shaker1_d']
shaker2 = parser.devices['shaker2_p']

shaker1.relatives.entrypoint.get_node_args()
# Out:
# {'x': 289.5, 'y': 55.5, 'z': 124.5, 'roll': 180.0, 'pitch': 0.0, 'yaw': 0.0}

# %%
parser.summarise()
# Out:
# ┏━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┓
# ┃         ┃          ┃          ┃       ┃          ┃        ┃          ┃          ┃ Plate    ┃         ┃          ┃
# ┃         ┃ Device   ┃          ┃       ┃          ┃        ┃ Relative ┃          ┃ path     ┃ Relati… ┃ Relative ┃
# ┃ Node ID ┃ type     ┃ Label    ┃ Index ┃ Side     ┃ Action ┃ positio… ┃ Origin   ┃ nodes    ┃ entryp… ┃ positio… ┃
# ┡━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━┩
# │ 0       │ robotarm │ robotarm │ None  │          │        │ 0        │ [        │ 0        │ [       │ 0        │
# │         │          │          │       │          │        │          │ 0.0      │          │ 149.6   │          │
# │         │          │          │       │          │        │          │ 0.0      │          │ -0.9    │          │
# ...

# %%
g, net = parser.make_graph(conf.LOCAL_DIR / "device_graph.gml", visualise=True)
